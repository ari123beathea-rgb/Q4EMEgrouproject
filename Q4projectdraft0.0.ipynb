# %% [markdown]
# <a href="https://colab.research.google.com/github/ari123beathea-rgb/Q4EMEgrouproject/blob/main/Q4project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
intro()
start()
worktimerprocess()
# Out:
# Good day!
# How much time do you want to use?(in minutes) 200
# How long do you want to work per interval? 1
# How long do you want your breaks to be? 5
# Do you wish to start the timer? yes
# Timer complete!

# %%
import time

def intro():
 print ("Good day!")
 # Declare variables as global so other functions can access them.
 global overalltime, worktime, brek
 overalltime = int(input("How much time do you want to use?(in minutes) "))
 worktime = int(input("How long do you want to work per interval? "))
 brek = int(input("How long do you want your breaks to be? "))

def start():
 yesorno = ""
 while yesorno != "yes":
  yesorno = input("Do you wish to start the timer? ")

def worktimerprocess ():

  total_seconds = worktime * 60 # Convert worktime (minutes) to seconds

  while total_seconds >= 0:
    mins, sec = divmod(total_seconds, 60)
    timer_output = f'{mins:02d}:{sec:02d}' # Use a different variable name to avoid shadowing the 'time' module
    print (timer_output, end="\r")
    time.sleep(1)
    total_seconds -= 1


  print("Timer complete!     ")

# yo the timer isnt working, pero this all i got so far i fix bukas haha..
